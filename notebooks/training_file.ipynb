# %% [markdown]
# ## Connecting to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
darknet_path = '/content/drive/MyDrive/Projects/african-wildlife-detection/files/'
os.chdir(darknet_path)
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Projects/african-wildlife-detection/files

# %%
# !git clone https://github.com/AlexeyAB/darknet

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
#!vim Makefile
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# !nvidia-smi

# %%
# !tar -xzvf "/content/drive/MyDrive/cudnn-10.0-linux-x64-v7.5.0.56.tgz" -C /usr/local/
# !chmod a+r /usr/local/cuda/include/cudnn.h
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2

# %%
# from IPython.display import HTML
# from subprocess import getoutput
# s = getoutput('nvidia-smi')
# if 'K80' in s:
#     gpu = 'K80'
# elif 'T4' in s:
#     gpu = 'T4'
# elif 'P100' in s:
#     gpu = 'P100'
# else:
#     gpu='DONT PROCEED'
# display(HTML(f"<h1>{gpu}</h1>"))

# %%
# # make darknet (build)
# !make

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights

# %%
# !chmod +x ./darknet
# %cd /content/drive/MyDrive/Projects/african-wildlife-detection/files/darknet
# !./darknet
# Out:
# /content/drive/MyDrive/Projects/african-wildlife-detection/files/darknet
# usage: ./darknet <function>

# %% [markdown]
# ## Traing YOLOv3 on custom dataset

# %%
# !./darknet detector train /content/drive/MyDrive/Projects/african-wildlife-detection/files/labelled_data.data /content/drive/MyDrive/Projects/african-wildlife-detection/files/yolov3_train.cfg /content/drive/MyDrive/Projects/african-wildlife-detection/files/darknet/darknet53.conv.74  -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 537043, rewritten_bbox = 0.080627 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.894620), count: 4, class_loss = 0.020208, iou_loss = 0.043251, total_loss = 0.063459
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.858855), count: 3, class_loss = 0.136886, iou_loss = 0.067158, total_loss = 0.204044
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 537050, rewritten_bbox = 0.080626 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.902737), count: 5, class_loss = 0.000424, iou_loss = 0.074104, total_loss = 0.074528
# ...

# %%
# !./darknet detector train /content/drive/MyDrive/Projects/african-wildlife-detection/files/labelled_data.data /content/drive/MyDrive/Projects/african-wildlife-detection/files/yolov3_train.cfg /content/drive/MyDrive/Projects/african-wildlife-detection/files/weights/yolov3_train_last.weights  -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000007, iou_loss = 0.000000, total_loss = 0.000007
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 352225, rewritten_bbox = 0.091987 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.925087), count: 7, class_loss = 0.000325, iou_loss = 0.036337, total_loss = 0.036662
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.849096), count: 2, class_loss = 0.000279, iou_loss = 0.076532, total_loss = 0.076811
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...

# %% [markdown]
# ## Testing YOLOv3 model on custom test dataset

# %%
# !./darknet detector map /content/drive/MyDrive/Projects/african-wildlife-detection/files/labelled_data.data /content/drive/MyDrive/Projects/african-wildlife-detection/files/yolov3_test.cfg /content/drive/MyDrive/Projects/african-wildlife-detection/files/weights/yolov3_train_best.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
  # !./darknet detector demo /content/drive/MyDrive/Projects/african-wildlife-detection/files/labelled_data.data /content/drive/MyDrive/Projects/african-wildlife-detection/files/yolov3_test.cfg /content/drive/MyDrive/Projects/african-wildlife-detection/files/weights/yolov3_train_8000.weights -dont_show /content/drive/MyDrive/Projects/african-wildlife-detection/test-images-videos/elephant.mp4 -i 0 -out_filename /content/drive/MyDrive/Projects/african-wildlife-detection/test-images-videos/output/elephant.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
#  cvWriteFrame
# Objects:
#
# Elephant: 99%
# Elephant: 84%
#
# FPS:41.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# Elephant: 98%
# Elephant: 81%
#
# FPS:41.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# Elephant: 98%
# Elephant: 62%
#
# FPS:41.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# Elephant: 99%
# Elephant: 52%
# Elephant: 30%
#
# FPS:42.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# Elephant: 99%
# Elephant: 34%
#
# FPS:42.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# Elephant: 99%
#
# FPS:42.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# Elephant: 99%
#
# FPS:42.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# Elephant: 99%
#
# FPS:42.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# Elephant: 99%
# Elephant: 26%
#
# FPS:42.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# Elephant: 97%
#
# FPS:43.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# Elephant: 96%
#
# FPS:43.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# ...

# %%
  # !./darknet detector demo /content/drive/MyDrive/Projects/african-wildlife-detection/files/labelled_data.data /content/drive/MyDrive/Projects/african-wildlife-detection/files/yolov3_test.cfg /content/drive/MyDrive/Projects/african-wildlife-detection/files/weights/yolov3_train_8000.weights -dont_show /content/drive/MyDrive/Projects/african-wildlife-detection/test-images-videos/rhino1.mp4 -i 0 -out_filename /content/drive/MyDrive/Projects/african-wildlife-detection/test-images-videos/output/rhino1.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Rhino: 100%
# Rhino: 99%
#
# FPS:40.4 	 AVG_FPS:40.5
#
#  cvWriteFrame
# Objects:
#
# Rhino: 100%
# Rhino: 100%
#
# FPS:40.4 	 AVG_FPS:40.5
#
#  cvWriteFrame
# Objects:
#
# Rhino: 100%
# Rhino: 100%
#
# FPS:40.5 	 AVG_FPS:40.5
#
#  cvWriteFrame
# Objects:
#
# Rhino: 100%
# Rhino: 100%
#
# FPS:40.4 	 AVG_FPS:40.5
#
#  cvWriteFrame
# Objects:
#
# Rhino: 100%
# Rhino: 100%
#
# FPS:40.3 	 AVG_FPS:40.5
#
#  cvWriteFrame
# Objects:
#
# Rhino: 100%
# Rhino: 100%
#
# FPS:40.4 	 AVG_FPS:40.5
#
#  cvWriteFrame
# Objects:
#
# Rhino: 100%
# Rhino: 100%
#
# FPS:40.4 	 AVG_FPS:40.5
#
#  cvWriteFrame
# Objects:
#
# Rhino: 100%
# Rhino: 100%
#
# FPS:40.5 	 AVG_FPS:40.5
#
#  cvWriteFrame
# Objects:
#
# Rhino: 100%
# Rhino: 100%
#
# FPS:40.5 	 AVG_FPS:40.5
#
#  cvWriteFrame
# Objects:
#
# Rhino: 100%
# Rhino: 100%
#
# FPS:40.4 	 AVG_FPS:40.5
#
#  cvWriteFrame
# Objects:
#
# Rhino: 100%
# Rhino: 100%
#
# FPS:40.3 	 AVG_FPS:40.5
#
#  cvWriteFrame
# ...

# %%
  # !./darknet detector demo /content/drive/MyDrive/Projects/african-wildlife-detection/files/labelled_data.data /content/drive/MyDrive/Projects/african-wildlife-detection/files/yolov3_test.cfg /content/drive/MyDrive/Projects/african-wildlife-detection/files/weights/yolov3_train_8000.weights -dont_show /content/drive/MyDrive/Projects/african-wildlife-detection/test-images-videos/zebra1.mp4 -i 0 -out_filename /content/drive/MyDrive/Projects/african-wildlife-detection/test-images-videos/output/zebra1.mp4
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# Demo
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
  # !./darknet detector demo /content/drive/MyDrive/Projects/african-wildlife-detection/files/labelled_data.data /content/drive/MyDrive/Projects/african-wildlife-detection/files/yolov3_test.cfg /content/drive/MyDrive/Projects/african-wildlife-detection/files/weights/yolov3_train_8000.weights -dont_show /content/drive/MyDrive/Projects/african-wildlife-detection/test-images-videos/zebra-elephant-buffalo1.mp4 -i 0 -out_filename /content/drive/MyDrive/Projects/african-wildlife-detection/test-images-videos/output/zebra-elephant-buffalo1.mp4
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# Demo
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
